# %%
import pandas as pd

# %%
df=pd.read_csv("Tamil-Nadu_2015.csv")

# %%
df.head()
# Out:
#   Organic Farmers          Unnamed: 1   Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 0              No         Farmer Name  Farmer Type       State     District
# 1               1   Dinesh Geethchand   Individual  Tamil Nadu      Chennai
# 2               2       Rayson Rappai   Individual  Tamil Nadu  Coimbat ore
# 3               3  Bhaskar Karupannan   Individual  Tamil Nadu  Coimbat ore
# 4               4    Vijaykumar Kumar   Individual  Tamil Nadu  Coimbat ore
#
#                                           Unnamed: 5            Unnamed: 6  \
# 0                                   Complete Address                 Email
# 1  6/1, New No.29, East Jones Road,\nSaidapet Pin...                   NaN
# 2  Otr Illam, 1/60, Murugan Colony, T.V.S.Nagar, ...   fresh@otrfarms. com
# 3  Arya Organic Food Store, 240, Four Bangalow, N...  baskar77k@gma il.com
# 4  No:140,Sathya Sai Nagar,Annur Road,Mettupala y...                   NaN
#
# ...
